# %% [markdown]
# <a href="https://colab.research.google.com/github/Anil1331/EIP3-Assignments/blob/master/Yolo_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://keras.io/
# !pip install -q keras
import keras

import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.merge import concatenate

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 50
l = 10
num_filter = 20

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
input = Input(shape=(img_height, img_width, channel,))

# Layer 1
layer1 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input)
layer1 = BatchNormalization(name='norm_1')(layer1)
layer1 = LeakyReLU(alpha=0.1)(layer1)
layer1 = MaxPooling2D(pool_size=(2, 2))(layer1)

# Layer 2
layer2 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(layer1)
layer2 = BatchNormalization(name='norm_2')(layer2)
layer2 = LeakyReLU(alpha=0.1)(layer2)
layer2 = MaxPooling2D(pool_size=(2, 2))(layer2)

# Layer 3
layer3 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(layer2)
layer3 = BatchNormalization(name='norm_3')(layer3)
layer3 = LeakyReLU(alpha=0.1)(layer3)

# Layer 4
layer4 = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(layer3)
layer4 = BatchNormalization(name='norm_4')(layer4)
layer4 = LeakyReLU(alpha=0.1)(layer4)

# Layer 5
layer5 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(layer4)
layer5 = BatchNormalization(name='norm_5')(layer5)
layer5 = LeakyReLU(alpha=0.1)(layer5)
layer5 = MaxPooling2D(pool_size=(2, 2))(layer5)

# Layer 6
layer6 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(layer5)
layer6 = BatchNormalization(name='norm_6')(layer6)
layer6 = LeakyReLU(alpha=0.1)(layer6)

# Layer 7
layer7 = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(layer6)
layer7 = BatchNormalization(name='norm_7')(layer7)
layer7 = LeakyReLU(alpha=0.1)(layer7)

# Layer 8
layer8 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(layer7)
layer8 = BatchNormalization(name='norm_8')(layer8)
layer8 = LeakyReLU(alpha=0.1)(layer8)
layer8 = MaxPooling2D(pool_size=(2, 2))(layer8)

# Layer 9
layer9 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(layer8)
layer9 = BatchNormalization(name='norm_9')(layer9)
layer9 = LeakyReLU(alpha=0.1)(layer9)

# Layer 10
layer10 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(layer9)
layer10 = BatchNormalization(name='norm_10')(layer10)
layer10 = LeakyReLU(alpha=0.1)(layer10)

# Layer 11
layer11 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(layer10)
layer11 = BatchNormalization(name='norm_11')(layer11)
layer11 = LeakyReLU(alpha=0.1)(layer11)

# Layer 12
layer12 = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(layer11)
layer12 = BatchNormalization(name='norm_12')(layer12)
layer12 = LeakyReLU(alpha=0.1)(layer12)

skip_connection = layer12

# Layer 13
layer13 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(layer12)
layer13 = BatchNormalization(name='norm_13')(layer13)
layer13 = LeakyReLU(alpha=0.1)(layer13)

x = MaxPooling2D(pool_size=(2, 2))(layer13)

# Layer 14
layer14 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x)
layer14 = BatchNormalization(name='norm_14')(layer14)
layer14 = LeakyReLU(alpha=0.1)(layer14)

# Layer 15
layer15 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(layer14)
layer15 = BatchNormalization(name='norm_15')(layer15)
layer15 = LeakyReLU(alpha=0.1)(layer15)

# Layer 16
layer16 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(layer15)
layer16 = BatchNormalization(name='norm_16')(layer16)
layer16 = LeakyReLU(alpha=0.1)(layer16)

# Layer 17
layer17 = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(layer16)
layer17 = BatchNormalization(name='norm_17')(layer17)
layer17 = LeakyReLU(alpha=0.1)(layer17)

# Layer 18
layer18 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(layer17)
layer18 = BatchNormalization(name='norm_18')(layer18)
layer18 = LeakyReLU(alpha=0.1)(layer18)

# Layer 19
layer19 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(layer18)
layer19 = BatchNormalization(name='norm_19')(layer19)
layer19 = LeakyReLU(alpha=0.1)(layer19)

# Layer 20
layer20 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(layer19)
layer20 = BatchNormalization(name='norm_20')(layer20)
layer20 = LeakyReLU(alpha=0.1)(layer20)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x = concatenate([skip_connection, layer20])

# Layer 22
layer22 = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x)
layer22 = BatchNormalization(name='norm_22')(layer22)
layer22 = LeakyReLU(alpha=0.1)(layer22)

# Layer 23
layer23 = Flatten()(layer22)

output = Dense(num_classes, activation='softmax')(layer23)

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 32, 32, 32)   864         input_5[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 32, 32, 32)   128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_89 (LeakyReLU)      (None, 32, 32, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 16, 16, 32)   0           leaky_re_lu_89[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 16, 16, 64)   18432       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 16, 16, 64)   256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_90 (LeakyReLU)      (None, 16, 16, 64)   0           norm_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 8, 8, 64)     0           leaky_re_lu_90[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 8, 8, 128)    73728       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 8, 8, 128)    512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_91 (LeakyReLU)      (None, 8, 8, 128)    0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 8, 8, 64)     8192        leaky_re_lu_91[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 8, 8, 64)     256         conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_92 (LeakyReLU)      (None, 8, 8, 64)     0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 8, 8, 128)    73728       leaky_re_lu_92[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 8, 8, 128)    512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_93 (LeakyReLU)      (None, 8, 8, 128)    0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 4, 4, 128)    0           leaky_re_lu_93[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 4, 4, 256)    294912      max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_94 (LeakyReLU)      (None, 4, 4, 256)    0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 4, 4, 128)    32768       leaky_re_lu_94[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 4, 4, 128)    512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_95 (LeakyReLU)      (None, 4, 4, 128)    0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 4, 4, 256)    294912      leaky_re_lu_95[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_96 (LeakyReLU)      (None, 4, 4, 256)    0           norm_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 2, 2, 256)    0           leaky_re_lu_96[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 2, 2, 512)    1179648     max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 2, 2, 512)    2048        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_97 (LeakyReLU)      (None, 2, 2, 512)    0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_97[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_98 (LeakyReLU)      (None, 2, 2, 256)    0           norm_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_98[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_99 (LeakyReLU)      (None, 2, 2, 512)    0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_99[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_100 (LeakyReLU)     (None, 2, 2, 256)    0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_100[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_101 (LeakyReLU)     (None, 2, 2, 512)    0           norm_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 1, 1, 512)    0           leaky_re_lu_101[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 1, 1, 1024)   4718592     max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_102 (LeakyReLU)     (None, 1, 1, 1024)   0           norm_14[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_102[0][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_103 (LeakyReLU)     (None, 1, 1, 512)    0           norm_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_103[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_104 (LeakyReLU)     (None, 1, 1, 1024)   0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_104[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_105 (LeakyReLU)     (None, 1, 1, 512)    0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_105[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_106 (LeakyReLU)     (None, 1, 1, 1024)   0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_106[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 2, 2, 64)     16384       leaky_re_lu_100[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_107 (LeakyReLU)     (None, 1, 1, 1024)   0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 2, 2, 64)     256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_107[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_109 (LeakyReLU)     (None, 2, 2, 64)     0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 256)    0           leaky_re_lu_109[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_108 (LeakyReLU)     (None, 1, 1, 1024)   0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1, 1, 1280)   0           lambda_5[0][0]
#                                                                  leaky_re_lu_108[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 1, 1, 1024)   11796480    concatenate_5[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_110 (LeakyReLU)     (None, 1, 1, 1024)   0           norm_22[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 1024)         0           leaky_re_lu_110[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           10250       flatten_5[0][0]
# ==================================================================================================
# Total params: 50,541,802
# Trainable params: 50,521,130
# Non-trainable params: 20,672
# __________________________________________________________________________________________________

# %%
# determine Loss function and Optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 111s 2ms/step - loss: 1.4322 - acc: 0.4799 - val_loss: 1.7216 - val_acc: 0.4173
# Epoch 2/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.9929 - acc: 0.6466 - val_loss: 1.0406 - val_acc: 0.6408
# Epoch 3/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.7807 - acc: 0.7271 - val_loss: 0.8682 - val_acc: 0.7034
# Epoch 4/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.6494 - acc: 0.7735 - val_loss: 1.0959 - val_acc: 0.6636
# Epoch 5/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.5593 - acc: 0.8074 - val_loss: 1.2726 - val_acc: 0.6196
# Epoch 6/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.4725 - acc: 0.8371 - val_loss: 1.6904 - val_acc: 0.6106
# Epoch 7/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.4115 - acc: 0.8590 - val_loss: 0.8597 - val_acc: 0.7297
# Epoch 8/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.3514 - acc: 0.8779 - val_loss: 0.8528 - val_acc: 0.7387
# Epoch 9/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.2998 - acc: 0.8951 - val_loss: 0.9180 - val_acc: 0.7381
# Epoch 10/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.2548 - acc: 0.9116 - val_loss: 0.8680 - val_acc: 0.7460
# Epoch 11/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.2313 - acc: 0.9215 - val_loss: 0.8619 - val_acc: 0.7583
# Epoch 12/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1918 - acc: 0.9338 - val_loss: 1.1670 - val_acc: 0.6851
# Epoch 13/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1739 - acc: 0.9404 - val_loss: 1.0213 - val_acc: 0.7488
# Epoch 14/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1410 - acc: 0.9514 - val_loss: 1.0816 - val_acc: 0.7374
# Epoch 15/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.1243 - acc: 0.9571 - val_loss: 1.0527 - val_acc: 0.7579
# Epoch 16/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1114 - acc: 0.9622 - val_loss: 1.1766 - val_acc: 0.7405
# Epoch 17/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1027 - acc: 0.9649 - val_loss: 0.9827 - val_acc: 0.7761
# Epoch 18/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1027 - acc: 0.9646 - val_loss: 1.3490 - val_acc: 0.7285
# Epoch 19/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.1138 - acc: 0.9612 - val_loss: 1.5061 - val_acc: 0.6938
# Epoch 20/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0925 - acc: 0.9675 - val_loss: 1.0355 - val_acc: 0.7730
# Epoch 21/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0700 - acc: 0.9750 - val_loss: 1.1717 - val_acc: 0.7607
# Epoch 22/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0685 - acc: 0.9764 - val_loss: 1.1961 - val_acc: 0.7536
# Epoch 23/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0671 - acc: 0.9768 - val_loss: 1.1736 - val_acc: 0.7574
# Epoch 24/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0653 - acc: 0.9772 - val_loss: 1.1968 - val_acc: 0.7539
# Epoch 25/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0639 - acc: 0.9776 - val_loss: 1.1245 - val_acc: 0.7693
# Epoch 26/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0567 - acc: 0.9805 - val_loss: 1.1866 - val_acc: 0.7584
# Epoch 27/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0553 - acc: 0.9809 - val_loss: 1.2213 - val_acc: 0.7506
# Epoch 28/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0646 - acc: 0.9782 - val_loss: 1.2061 - val_acc: 0.7538
# Epoch 29/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0516 - acc: 0.9824 - val_loss: 1.0822 - val_acc: 0.7819
# Epoch 30/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0569 - acc: 0.9808 - val_loss: 1.3272 - val_acc: 0.7420
# Epoch 31/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0470 - acc: 0.9842 - val_loss: 1.2246 - val_acc: 0.7644
# Epoch 32/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0475 - acc: 0.9832 - val_loss: 1.1838 - val_acc: 0.7771
# Epoch 33/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0475 - acc: 0.9836 - val_loss: 1.2651 - val_acc: 0.7582
# Epoch 34/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0436 - acc: 0.9848 - val_loss: 1.2437 - val_acc: 0.7534
# Epoch 35/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.0495 - acc: 0.9830 - val_loss: 1.2031 - val_acc: 0.7676
# Epoch 36/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0411 - acc: 0.9861 - val_loss: 1.0740 - val_acc: 0.7904
# Epoch 37/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0381 - acc: 0.9873 - val_loss: 1.1690 - val_acc: 0.7773
# Epoch 38/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0359 - acc: 0.9883 - val_loss: 1.1039 - val_acc: 0.7916
# Epoch 39/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0386 - acc: 0.9874 - val_loss: 1.0983 - val_acc: 0.7848
# Epoch 40/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0371 - acc: 0.9872 - val_loss: 1.0702 - val_acc: 0.7888
# Epoch 41/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0353 - acc: 0.9877 - val_loss: 1.2915 - val_acc: 0.7667
# Epoch 42/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0358 - acc: 0.9875 - val_loss: 1.2273 - val_acc: 0.7654
# Epoch 43/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0312 - acc: 0.9897 - val_loss: 1.3336 - val_acc: 0.7643
# Epoch 44/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0359 - acc: 0.9880 - val_loss: 1.2240 - val_acc: 0.7864
# Epoch 45/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0567 - acc: 0.9819 - val_loss: 1.0396 - val_acc: 0.7831
# Epoch 46/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0293 - acc: 0.9902 - val_loss: 1.0399 - val_acc: 0.7962
# Epoch 47/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0255 - acc: 0.9916 - val_loss: 1.0955 - val_acc: 0.7926
# Epoch 48/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0322 - acc: 0.9890 - val_loss: 1.9006 - val_acc: 0.7038
# Epoch 49/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0302 - acc: 0.9902 - val_loss: 1.1207 - val_acc: 0.7801
# Epoch 50/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.0303 - acc: 0.9899 - val_loss: 1.0964 - val_acc: 0.7944

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Save the trained weights in to .h5 format
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
# Out:
# 10000/10000 [==============================] - 10s 970us/step
# Test loss: 1.0964057574480772
# Test accuracy: 0.7944
# Saved the model to disk

# %%
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
from google.colab import files

files.download('Yolo_Basic_model2.h5')
# Out:
# Saved the model to disk
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 40498, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 721, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 800, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d214d4bb6af2> in <module>()
#       3 from google.colab import files
#       4
# ----> 5 files.download('Yolo_Basic_model2.h5')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:
